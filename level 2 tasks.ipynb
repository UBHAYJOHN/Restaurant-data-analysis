# %% [markdown]
# # level 2 task 2

# %%
df=pd.read_csv('cleaned_task1.csv')
df.head(5)
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3        6318506                    Ooma           162  Mandaluyong City
# 4        6314302             Sambo Kojin           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# ...

# %%
from itertools import combinations

# %%
from collections import Counter

# %%
df=df.dropna(subset=['Cuisines'])

# %%
df['Cuisines']=df['Cuisines'].apply(lambda x: [i.strip() for i in x.split(',')])

# %%
pair_counter=Counter()

# %%
for Cuisines in df['Cuisines']:
    if len(Cuisines)>=2:
        pair=combinations(sorted(set(Cuisines)),2)
        pair_counter.update(pair)

# %%
combo_df=pd.DataFrame(pair_counter.items(),columns=['cuisines_pairs','pair'])

# %%
combo_df = combo_df.sort_values(by='pair', ascending=False)

# %%
print(combo_df.columns)
# Out:
# Index(['cuisines_pairs', 'pair'], dtype='object')

# %%
print(combo_df.head(10))
# Out:
#                    cuisines_pairs  pair
# 379       (Chinese, North Indian)  1782
# 368       (Mughlai, North Indian)   831
# 421     (Fast Food, North Indian)   485
# 408   (Continental, North Indian)   468
# 439          (Chinese, Fast Food)   466
# 392  (North Indian, South Indian)   405
# 403            (Chinese, Mughlai)   379
# 391       (Chinese, South Indian)   344
# 279        (Chinese, Continental)   303
# 418       (Italian, North Indian)   295

# %% [markdown]
# #task 3

# %% [markdown]
# Determine if certain cuisine combinations tend to have higher ratings

# %%
from collections import defaultdict

# %%
df.head(10)
# Out:
#    Restaurant ID                           Restaurant Name  Country Code  \
# 0        6317637                          Le Petit Souffle           162
# 1        6304287                          Izakaya Kikufuji           162
# 2        6300002                    Heat - Edsa Shangri-La           162
# 3        6318506                                      Ooma           162
# 4        6314302                               Sambo Kojin           162
# 5       18189371                              Din Tai Fung           162
# 6        6300781                                Buffet 101           162
# 7        6301290                                   Vikings           162
# 8        6300010  Spiral - Sofitel Philippine Plaza Manila           162
# 9        6314987                                  Locavore           162
#
#                City                                            Address  \
# 0       Makati City  Third Floor, Century City Mall, Kalayaan Avenu...
# ...

# %%
df=df.dropna(subset=['Aggregate rating'])

# %%
df.tail(10)
# Out:
#       Restaurant ID           Restaurant Name  Country Code       City  \
# 9541        5905215           Emirgan S�_ti��           208  ��stanbul
# 9542        5926979            Leman K�_lt�_r           208  ��stanbul
# 9543        5916085              Dem Karak�_y           208  ��stanbul
# 9544        5915547     Karak�_y G�_ll�_o��lu           208  ��stanbul
# 9545        5915054                  Baltazar           208  ��stanbul
# 9546        5915730               Naml۱ Gurme           208  ��stanbul
# 9547        5908749              Ceviz A��ac۱           208  ��stanbul
# 9548        5915807                     Huqqa           208  ��stanbul
# 9549        5916112               A���k Kahve           208  ��stanbul
# 9550        5927402  Walter's Coffee Roastery           208  ��stanbul
#
#                                                 Address         Locality  \
# 9541  Emirgan Mahallesi, Sak۱p Sabanc۱ Caddesi, No 4...         Emirg��n
# ...

# %%
pair_ratings=defaultdict(list)

# %%
for _,row in df.iterrows():
    cuisines=sorted(set(rows['Cuisines']))
    rating=row['Aggregate rating']
    if len(cuisines)>=2:
        pairs=combinations(cuisines,2)
        for pair in pairs:
            pair_ratings[pair].append(rating)

# %%
# now we need to use the avg of rating ,the reason is  it normalizes multiple entries per pair

# %%
avg_rating_data = [(pair, sum(ratings) / len(ratings)) for pair, ratings in pair_ratings.items()]
rating_df = pd.DataFrame(avg_rating_data, columns=['Cuisine_Pair', 'Average_Rating'])

# %%
print(rating_df)
# Out:
#            Cuisine_Pair  Average_Rating
# 0    (Desserts, French)         2.66637
# 1  (Desserts, Japanese)         2.66637
# 2    (French, Japanese)         2.66637

# %%
rating_df=rating_df.sort_values(by='Average_Rating',ascending=False)

# %%
print(rating_df)
# Out:
#            Cuisine_Pair  Average_Rating
# 0    (Desserts, French)         2.66637
# 1  (Desserts, Japanese)         2.66637
# 2    (French, Japanese)         2.66637

# %%
high_rating_combos = rating_df[rating_df['Average_Rating'] > 4.0]
print(high_rating_combos)
# Out:
# Empty DataFrame
# Columns: [Cuisine_Pair, Average_Rating]
# Index: []

# %% [markdown]
# level 2 task 3 q2:  Identify any patterns or clusters of
#  restaurants in specific areas.

# %%
area_counts = df['Locality'].value_counts().reset_index()
area_counts.columns = ['Locality', 'Restaurant_Count']

# %%
print(area_counts.head(10))
# Out:
#               Locality  Restaurant_Count
# 0      Connaught Place               122
# 1       Rajouri Garden                99
# 2             Shahdara                87
# 3       Defence Colony                86
# 4        Malviya Nagar                85
# 5            Pitampura                85
# 6  Mayur Vihar Phase 1                84
# 7       Rajinder Nagar                81
# 8           Safdarjung                80
# 9         Satyaniketan                79

# %% [markdown]
# task 4 : Q 1: Identify if there are any restaurant chains
#  present in the dataset

# %%
chain_counts = df['Restaurant Name'].value_counts()
print(chain_counts)
# Out:
# Restaurant Name
# Cafe Coffee Day             83
# Domino's Pizza              79
# Subway                      63
# Green Chick Chop            51
# McDonald's                  48
#                             ..
# Odeon Social                 1
# Johnny Rockets               1
# House of Commons             1
# HotMess                      1
# Walter's Coffee Roastery     1
# Name: count, Length: 7446, dtype: int64

# %%
restaurant_chains = chain_counts[chain_counts > 1]

# %%
print(restaurant_chains)
# Out:
# Restaurant Name
# Cafe Coffee Day       83
# Domino's Pizza        79
# Subway                63
# Green Chick Chop      51
# McDonald's            48
#                       ..
# Town Hall              2
# Halki Aanch            2
# Snack Junction         2
# Delhi Biryani Hut      2
# Beliram Degchiwala     2
# Name: count, Length: 734, dtype: int64

# %%
restaurant_chains.count().sum()
# Out:
# 734

# %% [markdown]
#  so  Total 734 restaurant chain presernt in dataset
